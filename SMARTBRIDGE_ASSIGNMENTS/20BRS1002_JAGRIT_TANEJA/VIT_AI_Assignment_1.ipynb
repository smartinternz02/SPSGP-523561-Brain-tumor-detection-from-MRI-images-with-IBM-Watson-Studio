# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.rand(16).reshape(4,4))
df
# Out:
#           0         1         2         3
# 0  0.884148  0.730874  0.701770  0.848597
# 1  0.822449  0.165117  0.941071  0.791970
# 2  0.033163  0.764138  0.898570  0.387859
# 3  0.847415  0.321897  0.905337  0.906027

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.884148        0.730874        0.701770        0.848597
# 1        0.822449        0.165117        0.941071        0.791970
# 2        0.033163        0.764138        0.898570        0.387859
# 3        0.847415        0.321897        0.905337        0.906027

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.646794        0.495506        0.861687        0.733613
# std          0.409871        0.298249        0.108230        0.235159
# min          0.033163        0.165117        0.701770        0.387859
# 25%          0.625127        0.282702        0.849370        0.690942
# 50%          0.834932        0.526385        0.901954        0.820283
# 75%          0.856598        0.739190        0.914271        0.862954
# max          0.884148        0.764138        0.941071        0.906027

# %%
null=df.isnull().sum()
print(null,"\n")

data_types=df.dtypes
print(data_types)
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64
#
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %%
df.iloc[0:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.730874        0.701770
# 1        0.165117        0.941071
# 2        0.764138        0.898570
# 3        0.321897        0.905337

# %%
df.loc[0:,'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.730874        0.701770
# 1        0.165117        0.941071
# 2        0.764138        0.898570
# 3        0.321897        0.905337
